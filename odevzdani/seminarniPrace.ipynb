# %%
# cíl 1

# %%
import re
import csv

file = open("/Users/ondrejbruha/Documents/GitHub/scientificProject/data/dinolist.txt")
lines = file.readlines()
header = lines[0]
header = header.split(",")
feetIndex = header.index('"feet"')
yearIndex = header.index('"year"')
miliIndex = header.index('"million_years"')
clean = []
for l in lines:
    line = l.split(",")
    newLine = []
    for i in line:
        if i == "NA" or i == '"ne"' or i == '"nezname"':
            newLine.append(0)
        elif i == '"detected"':
            newLine.append(True)
        elif line.index(i) == feetIndex or line.index(i) == yearIndex or line.index(i) == miliIndex:
            newLine.append(re.findall("[0-9]+", i))
        else:
            newLine.append(i)
    clean.append(newLine)
with open("/Users/ondrejbruha/Documents/GitHub/scientificProject/data/DinoClean.csv", "r+") as file:
    writer = csv.writer(file)
    writer.writerows(clean)

# %%
# cíl 2

# %%
import csv

data = []
with open("/Users/ondrejbruha/Documents/GitHub/scientificProject/data/oblast_A.csv", "r") as file:
    reader = csv.DictReader(file)
    for row in reader:
        data.append(row)
with open("/Users/ondrejbruha/Documents/GitHub/scientificProject/data/oblast_B.csv", "r") as file:
    reader = csv.DictReader(file)
    for row in reader:
        data.append(row)

with open("/Users/ondrejbruha/Documents/GitHub/scientificProject/data/oblast_C.csv", "r") as file:
    reader = csv.DictReader(file)
    for row in reader:
        data.append(row)

with open("/Users/ondrejbruha/Documents/GitHub/scientificProject/data/oblast_D.csv", "r") as file:
    reader = csv.DictReader(file)
    for row in reader:
        data.append(row)

with open("/Users/ondrejbruha/Documents/GitHub/scientificProject/data/oblast_E.csv", "r") as file:
    reader = csv.DictReader(file)
    for row in reader:
        data.append(row)
with open("/Users/ondrejbruha/Documents/GitHub/scientificProject/data/oblast_F.csv", "r") as file:
    reader = csv.DictReader(file)
    for row in reader:
        data.append(row)
with open("/Users/ondrejbruha/Documents/GitHub/scientificProject/data/oblast_G.csv", "r") as file:
    reader = csv.DictReader(file)
    for row in reader:
        data.append(row)
with open("/Users/ondrejbruha/Documents/GitHub/scientificProject/data/oblast_H.csv", "r") as file:
    reader = csv.DictReader(file)
    for row in reader:
        data.append(row)
with open("/Users/ondrejbruha/Documents/GitHub/scientificProject/data/oblast_I.csv", "r") as file:
    reader = csv.DictReader(file)
    for row in reader:
        data.append(row)
with open("/Users/ondrejbruha/Documents/GitHub/scientificProject/data/oblast_J.csv", "r") as file:
    reader = csv.DictReader(file)
    for row in reader:
        data.append(row)
with open("/Users/ondrejbruha/Documents/GitHub/scientificProject/data/oblast_K.csv", "r") as file:
    reader = csv.DictReader(file)
    for row in reader:
        data.append(row)
with open("/Users/ondrejbruha/Documents/GitHub/scientificProject/data/oblast_L.csv", "r") as file:
    reader = csv.DictReader(file)
    for row in reader:
        data.append(row)
with open("/Users/ondrejbruha/Documents/GitHub/scientificProject/data/oblast_M.csv", "r") as file:
    reader = csv.DictReader(file)
    for row in reader:
        data.append(row)
with open("/Users/ondrejbruha/Documents/GitHub/scientificProject/data/oblast_N.csv", "r") as file:
    reader = csv.DictReader(file)
    for row in reader:
        data.append(row)
table = {}
for d in data:
    table[d["dinosaurus"]] = d["dinosaurus"]

aggTable = []
for t in table:
    aggTable.append([t])


def findIndex(str):
    for i in range(len(aggTable)):
        if aggTable[i][0] == str:
            return i


for d in data:
    i = findIndex(d["dinosaurus"])
    aggTable[i].append(0)
    aggTable[i].append(0)
    aggTable[i].append(0)
    aggTable[i].append(0)
    aggTable[i].append(0)
    aggTable[i].append(0)
    aggTable[i].append(0)
    aggTable[i].append(0)
    aggTable[i].append(0)
    aggTable[i].append(0)
    aggTable[i][1] += int(d["rok_1986"])
    aggTable[i][2] += int(d["rok_1987"])
    aggTable[i][3] += int(d["rok_1988"])
    aggTable[i][4] += int(d["rok_1989"])
    aggTable[i][5] += int(d["rok_1989"])
    aggTable[i][6] += int(d["rok_1991"])
    aggTable[i][7] += int(d["rok_1992"])
    aggTable[i][8] += int(d["rok_1993"])
    aggTable[i][9] += int(d["rok_1994"])
    aggTable[i][10] += int(d["rok_1995"])
tableTowrite = []
for a in aggTable:
    row = []
    for b in a:
        if b:
            row.append(b)
    tableTowrite.append(row)

for arr in tableTowrite:
    if type(arr[0]) == type(1):
        tableTowrite.remove(arr)


def sortFunction(arr):
    return arr[0]


tableTowrite.sort(key=sortFunction)

with open("/Users/ondrejbruha/Documents/GitHub/scientificProject/data/agregace.csv", "r+") as file:
    writer = csv.writer(file)
    writer.writerows(tableTowrite)
